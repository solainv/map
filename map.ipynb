# %% [markdown]
# # Maps mit Markers

# %% [markdown]
# ### Definition:
# Eine "Map mit Markern" ist eine Karte, auf der bestimmte Standorte oder Punkte durch Marker oder Symbole gekennzeichnet sind. Diese Marker können unterschiedliche Formen, Farben oder Symbole haben und dienen dazu, spezifische Orte oder interessante Punkte auf der Karte hervorzuheben.
#
# ### Verwendung:
# - Eignet sich für Räumliche Daten
# - Wichtige Standorte markieren.
# - Navigation erleichtern
# - In interaktiven Kartenanwendungen können Marker oft angeklickt oder angetippt werden, um weitere Informationen anzuzeigen

# %%
import folium

# %% [markdown]
# ### Deutschlandskarte anzeigen:

# %%
latitude = 51.1657
longitude = 10.4527
germany_map = folium.Map(location=[latitude, longitude], zoom_start=5)
germany_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68d30445c88a5300fe9151b8ae98f85d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68d30445c88a5300fe9151b8ae98f85d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68d30445c88a5300fe9151b8ae98f85d = L.map(
#                 &quot;map_68d30445c88a5300fe9151b8ae98f85d&quot;,
#                 {
#                     center: [51.1657, 10.4527],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1d05a0edc58f840b00a274aa59925d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b1d05a0edc58f840b00a274aa59925d1.addTo(map_68d30445c88a5300fe9151b8ae98f85d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %% [markdown]
# # Maps with Markers <a id="6"></a>

# %%
# Daten importieren
df = pd.read_csv('https://raw.githubusercontent.com/solainv/map/main/sanfransicco.csv')

# %% [markdown]
# Let's take a look at the first five items in our dataset.

# %%
df.head(2)
# Out:
#    IncidntNum     Category                                        Descript  \
# 0   120058272  WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272  WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
#
#   DayOfWeek                    Date   Time PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
#
#                   Address           X          Y  \
# 0  800 Block of BRYANT ST -122.403405  37.775421
# 1  800 Block of BRYANT ST -122.403405  37.775421
#
#                                Location            PdId
# 0  (37.775420706711, -122.403404791479)  12005827212120
# 1  (37.775420706711, -122.403404791479)  12005827212168

# %% [markdown]
# ### Übericht über Daten
# > 1. **IncidntNum**: Vorfallsnummer
# > 2. **Category**:  Kategorie des Verbrechens oder Vorfalls
# > 3. **Descript**: Beschreibung des Verbrechens oder Vorfalls
# > 4. **DayOfWeek**: Der Wochentag, an dem der Vorfall stattgefunden hat
# > 5. **Date**: Das Datum, an dem der Vorfall stattgefunden hat
# > 6. **Time**: Die Tageszeit, zu der der Vorfall stattgefunden hat
# > 7. **PdDistrict**: Der Polizeibezirk
# > 8. **Resolution**: Die Auflösung des Verbrechens in Bezug darauf, ob der Täter verhaftet wurde oder nicht
# > 9. **Address**: Die nächstgelegene Adresse zum Ort des Vorfalls
# > 10. **X**:  Der Längengradwert des Ortes des Verbrechens
# > 11. **Y**: Der Breitengradwert des Ortes des Verbrechens
# > 12. **Location**: Der Breitengradwert des Ortes des Verbrechens
# > 13. **PdId**: Die Polizeibehörden-ID

# %%
df= pd.read_csv('sanfransicco.csv')

# %%
# Breitengradwert und Längengradwert von San Fransisco
latitude = 37.77
longitude = -122.42
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# %%
# FeatureGroup für die Vorfälle erstellen
fea_grp = folium.map.FeatureGroup()

# jedem Datenpunkt (X,Y) einen CircleMarker hinzufügen
for lat, lng in zip(df['Y'], df['X']):
    fea_grp.add_child(folium.vector_layers.CircleMarker([lat, lng], color='black',radius=5))

# jedem Marker eine Beschreibung hinzufügen
latitudes = list(df['Y'])
longitudes = list(df['X'])
labels = list(df['Category'])

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(sanfran_map)

# FeatureGroup zur Karte hinzufügen
sanfran_map.add_child(fea_grp)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aea294170c23e2c76bd3323eb87bf9be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aea294170c23e2c76bd3323eb87bf9be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aea294170c23e2c76bd3323eb87bf9be = L.map(
#                 &quot;map_aea294170c23e2c76bd3323eb87bf9be&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6ce01cf797978f988142722731d8f0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f6ce01cf797978f988142722731d8f0f.addTo(map_aea294170c23e2c76bd3323eb87bf9be);
#
#
#             var marker_a91d8feb6c58ee96438de2501e69b6d2 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(map_aea294170c23e2c76bd3323eb87bf9be);
#
#
#         var popup_479c6150b6ec781e718fd44ff93f8d76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c31b75c3ede05e6023c6a74e2c93d2ef = $(`&lt;div id=&quot;html_c31b75c3ede05e6023c6a74e2c93d2ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_479c6150b6ec781e718fd44ff93f8d76.setContent(html_c31b75c3ede05e6023c6a74e2c93d2ef);
#
#
#
#         marker_a91d8feb6c58ee96438de2501e69b6d2.bindPopup(popup_479c6150b6ec781e718fd44ff93f8d76)
#         ;
#
#
#
#
#             var marker_b6cbdb979cc32eb4ea64616716bfcc87 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(map_aea294170c23e2c76bd3323eb87bf9be);
#
#
#         var popup_7e08787469899a6ea0678b9c3a6fe556 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8a789c77621ff1e59e152b8bcb29a5d = $(`&lt;div id=&quot;html_f8a789c77621ff1e59e152b8bcb29a5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_7e08787469899a6ea0678b9c3a6fe556.setContent(html_f8a789c77621ff1e59e152b8bcb29a5d);
#
#
#
#         marker_b6cbdb979cc32eb4ea64616716bfcc87.bindPopup(popup_7e08787469899a6ea0678b9c3a6fe556)
#         ;
#
#
#
#
#             var marker_ec1a2189fba5afc12fcac28658d7f127 = L.marker(
#                 [37.7299809672996, -122.388856204292],
#                 {}
#             ).addTo(map_aea294170c23e2c76bd3323eb87bf9be);
#
#
#         var popup_276d4fd5c314c4436ff89781cfa62e47 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98dc96cd33b3150199277ec910611c0c = $(`&lt;div id=&quot;html_98dc96cd33b3150199277ec910611c0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#                 popup_276d4fd5c314c4436ff89781cfa62e47.setContent(html_98dc96cd33b3150199277ec910611c0c);
#
#
#
#         marker_ec1a2189fba5afc12fcac28658d7f127.bindPopup(popup_276d4fd5c314c4436ff89781cfa62e47)
#         ;
#
#
#
#
#             var marker_dd8e5f7165f8ef80f4b11f7508f19fef = L.marker(
#                 [37.7857883766888, -122.412970537591],
#                 {}
#             ).addTo(map_aea294170c23e2c76bd3323eb87bf9be);
#
#
#         var popup_1977faceb570e1c009abac06aae29d66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5a174b9476c481edb57e2bf79c3c654 = $(`&lt;div id=&quot;html_a5a174b9476c481edb57e2bf79c3c654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_1977faceb570e1c009abac06aae29d66.setContent(html_a5a174b9476c481edb57e2bf79c3c654);
#
#
#
#         marker_dd8e5f7165f8ef80f4b11f7508f19fef.bindPopup(popup_1977faceb570e1c009abac06aae29d66)
#         ;
#
#
#
#
#             var marker_810cbe0c32ffc07dfd98e85c409a0d20 = L.marker(
#                 [37.7650501214668, -122.419671780296],
#                 {}
#             ).addTo(map_aea294170c23e2c76bd3323eb87bf9be);
#
#
#         var popup_a670b11ee8ceaf42ea87f720896f2a90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed5dccc4a75eec7f699e1643610ebb48 = $(`&lt;div id=&quot;html_ed5dccc4a75eec7f699e1643610ebb48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_a670b11ee8ceaf42ea87f720896f2a90.setContent(html_ed5dccc4a75eec7f699e1643610ebb48);
#
#
#
#         marker_810cbe0c32ffc07dfd98e85c409a0d20.bindPopup(popup_a670b11ee8ceaf42ea87f720896f2a90)
#         ;
#
#
#
#
#             var marker_7edb580fb258f9219b23c68230954f51 = L.marker(
#                 [37.788018555829, -122.426077177375],
